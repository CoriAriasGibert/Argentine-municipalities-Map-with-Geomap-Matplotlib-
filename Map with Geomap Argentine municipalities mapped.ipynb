# %%
# Import geopandas library
import geopandas as gpd

# Load file
url = "https://infra.datos.gob.ar/catalog/modernizacion/dataset/7/distribution/7.14/download/municipios.geojson"
geoData = gpd.read_file(url)

# %%
geoData.head(2)
# Out:
#                 nombre_completo                    fuente      nombre      id  \
# 0          Municipio Abra Pampa  Direc. Grl. de Inmuebles  Abra Pampa  380014
# 1  Comisión Municipal Abralaite  Direc. Grl. de Inmuebles   Abralaite  386014
#
#                                            provincia           categoria  \
# 0  {'nombre': 'Jujuy', 'id': '38', 'interseccion'...           Municipio
# 1  {'nombre': 'Jujuy', 'id': '38', 'interseccion'...  Comisión Municipal
#
#                       geometry
# 0  POINT (-66.03227 -22.84314)
# 1  POINT (-65.79221 -23.13589)

# %%
# Import the geoplot library.
import matplotlib.pyplot as plt

# Set the plot size for this notebook:
plt.rcParams["figure.figsize"]=13,13

# Draw a map with matplotlib
geoData.plot(color="pink", edgecolor='deeppink', linewidth=.5);
plt.axis('on');
